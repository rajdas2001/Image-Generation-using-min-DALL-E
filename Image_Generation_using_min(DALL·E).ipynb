# %% [markdown]
# <a href="https://colab.research.google.com/github/rajdas2001/Image-Generation-using-min-DALL-E/blob/main/Image_Generation_using_min(DALL%C2%B7E).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install min-dalle -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from min_dalle import MinDalle

model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# %%time

text = input("Enter your idea: ")
seed = 6
grid_size = 2

display(model.generate_image(text, seed, grid_size))
# Out:
# Enter your idea: Robots chilling on a sunny beach
# <PIL.Image.Image image mode=RGB size=512x512>
# CPU times: user 29.9 s, sys: 248 ms, total: 30.1 s
# Wall time: 46.4 s
